# %% [markdown]
# # Python vs C++   -  Visualized

# %% [markdown]
# ### * The C++ execution is much faster than Python
# ### * C++ maxes out around 4 millions pixels processed per second
# ### * Python maxes out around 60 thousand pixels processes per second

# %% [markdown]
# ![py v cpp](./imgs/py_v_cpp.png)

# %% [markdown]
# # Load Results from Python and C++ executions

# %%
import pandas as pd
df = pd.read_csv("./results/py_v_cpp.3.csv")
df
# Out:
#            time  recursion_count  image_size  pixels_calculated  cpp_seconds  \
# 0  1.554326e+09                1      819200             819200     0.353648
# 1  1.554326e+09                5      819200            4076830     1.167788
# 2  1.554326e+09               10      819200            8105885     2.623797
# 3  1.554326e+09               20      819200           16021670     4.701991
# 4  1.554326e+09               40      819200           31290940     7.498040
# 5  1.554327e+09               80      819200           59636280    14.591326
# 6  1.554328e+09              160      819200          108002160    25.343019
#
#    cpp_pixels_per_second  python_seconds  python_pixels_per_second
# 0           2.316430e+06       13.810948              59315.262517
# 1           3.491072e+06       67.028245              60822.568183
# 2           3.089372e+06      138.626043              58473.031717
# 3           3.407422e+06      262.764785              60973.429244
# 4           4.173216e+06      511.658984              61155.849800
# 5           4.087105e+06      981.518046              60759.229257
# 6           4.261614e+06     1690.255531              63896.942225

# %% [markdown]
# # Shape Data for Visualization

# %% [markdown]
# ### drop unused columns

# %%
df = df.drop(['time','image_size','cpp_seconds','python_seconds','pixels_calculated'], axis=1)
df
# Out:
#    recursion_count  cpp_pixels_per_second  python_pixels_per_second
# 0                1           2.316430e+06              59315.262517
# 1                5           3.491072e+06              60822.568183
# 2               10           3.089372e+06              58473.031717
# 3               20           3.407422e+06              60973.429244
# 4               40           4.173216e+06              61155.849800
# 5               80           4.087105e+06              60759.229257
# 6              160           4.261614e+06              63896.942225

# %% [markdown]
# ### rename columns

# %%
df['recursions'] = df.recursion_count
df['Python'] = df.python_pixels_per_second
df['Cpp']    = df.cpp_pixels_per_second
df = df.drop(['recursion_count','cpp_pixels_per_second','python_pixels_per_second'], axis=1)
df
# Out:
#    recursions        Python           Cpp
# 0           1  59315.262517  2.316430e+06
# 1           5  60822.568183  3.491072e+06
# 2          10  58473.031717  3.089372e+06
# 3          20  60973.429244  3.407422e+06
# 4          40  61155.849800  4.173216e+06
# 5          80  60759.229257  4.087105e+06
# 6         160  63896.942225  4.261614e+06

# %% [markdown]
# ### convert recursion counts to labels

# %%
df.recursions = [str(i) for i in df.recursions.tolist()]
df.recursions.tolist()
# Out:
# ['1', '5', '10', '20', '40', '80', '160']

# %% [markdown]
# ### pixels to megapixels

# %%
df.Python = [round(i/1000000,4) for i in df.Python ]
df.Cpp = [ round(i/1000000,4) for i in df.Cpp ] 
df
# Out:
#   recursions  Python     Cpp
# 0          1  0.0593  2.3164
# 1          5  0.0608  3.4911
# 2         10  0.0585  3.0894
# 3         20  0.0610  3.4074
# 4         40  0.0612  4.1732
# 5         80  0.0608  4.0871
# 6        160  0.0639  4.2616

# %% [markdown]
# # Visualize Comparison

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_notebook, reset_output
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure
from bokeh.palettes import Spectral6
from bokeh.transform import dodge
from bokeh.transform import factor_cmap
reset_output()
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1710">Loading BokehJS ...</span>
#     </div>

# %%
x_max  = max(df.recursions)
y_max  = max(df.Cpp) + 0.4
source = ColumnDataSource(data=df)
width  = 0.40
alpha  = 0.8
ticker_buffer = 0.22

p = figure(
    x_range=df.recursions, y_range=(0, y_max), 
    plot_height=600,plot_width=970,
    title="Megapixels Processed per Second"
)
p.vbar(
    x=dodge('recursions', 0-ticker_buffer, range=p.x_range), 
    top='Python', 
    width=width, source=source,alpha=alpha,
    color="#e84d60",legend=value("Python")
)
p.vbar(
    x=dodge('recursions',  ticker_buffer,  range=p.x_range), 
    top='Cpp', 
    width=width, source=source,alpha=alpha,
    color="#718dbf", legend=value("C++")
)
p.x_range.range_padding = 0.01
p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "vertical"
p.xaxis.axis_label = "Recursions"
p.xaxis.axis_line_width = 0.1
p.yaxis.axis_line_width = 0.1
p.yaxis.major_label_text_color = "orange"
p.yaxis.major_label_orientation = "vertical"

show(p)
# Out:
#   <div class="bk-root" id="01982e31-1b89-40d1-a194-31eeb50ea652"></div>

# %% [markdown]
# # NEXT - easy "Pooling Convolution" with GPU

# %% [markdown]
# http://localhost:8888/notebooks/5_Calling_GPU_CUDA_code_from_Python.ipynb

# %% [markdown]
# ![raw](./imgs/rari.jpg)
